# %% [markdown]
# ### **Packages & Functions**

# %%
### PACKAGES

import ipywidgets as widgets
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from ipywidgets import fixed

# %%
### CONSTANTS

from src.configs import constants, ml_config, names

# %%
### FUNCTIONS

from src.libs.preprocessing import (
    load_data_from_local,
    preprocessing_learning_data,
    preprocessing_testing_data,
)

from src.libs.visualization import (
    plot_slider_scatter_feature,
    plot_slider_boxplot,
    plot_correlation_with_target,
    plot_correlation_matrix,
)

# %%
### IMPORT DATA

df_learning = load_data_from_local(True)

# %% [markdown]
# ## **Scatter plots**

# %%
plot_slider_scatter_feature(df=df_learning, subset_features=None)
# Out:
# interactive(children=(Dropdown(description='Feature 1', options=('id', 'feature_1', 'feature_2', 'target'), va…

# %% [markdown]
# ## **Boxplots**

# %%
plot_slider_boxplot(df=df_learning, subset_features=None)
# Out:
# interactive(children=(Dropdown(description='Feature', options=('id', 'feature_1', 'feature_2', 'target'), valu…

# %% [markdown]
# ## **Correlations**

# %%
plot_correlation_with_target(df=df_learning, top_k=10)
# Out:
# c:\Users\jules\Documents\Code\test\src\libs\visualization.py:111: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_k_features.index, y=top_k_features.values, palette="coolwarm")

# %%
plot_correlation_matrix(df=df_learning, subset_features=None)
